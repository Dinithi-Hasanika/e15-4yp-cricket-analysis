# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load data file
data = pd.read_csv('allMatchData.csv')

# %%
data.head()
# Out:
#    Innings ID         Team Day_Night  Home       Ground Result  Toss  Bat  \
# 0        1016  Afghanistan        DN     0  Dubai (DSC)   lost  lost  1st
# 1        1025  Afghanistan         D     0  Dubai (DSC)    won  lost  1st
# 2        1068  Afghanistan        DN     0     Canberra   lost  lost  2nd
# 3        1074  Afghanistan         D     0      Dunedin   lost  lost  1st
# 4        1092  Afghanistan        DN     0        Perth   lost   won  2nd
#
#      Opposition            p1             p2             p3  \
# 0     v Ireland  Javed Ahmadi    Usman Ghani    Afsar Zazai
# 1     v Ireland  Javed Ahmadi    Usman Ghani  Asghar Afghan
# 2  v Bangladesh  Javed Ahmadi    Afsar Zazai  Nawroz Mangal
# 3   v Sri Lanka  Javed Ahmadi  Nawroz Mangal  Asghar Afghan
# 4   v Australia  Javed Ahmadi    Usman Ghani  Nawroz Mangal
#
#                    p4                  p5                 p6  \
# 0         Nasir Jamal       Asghar Afghan      Mohammad Nabi
# 1  Samiullah Shinwari       Mohammad Nabi  Najibullah Zadran
# 2       Asghar Afghan  Samiullah Shinwari      Mohammad Nabi
# 3  Samiullah Shinwari       Mohammad Nabi  Najibullah Zadran
# 4       Asghar Afghan  Samiullah Shinwari      Mohammad Nabi
#
#                   p7              p8             p9           p10  \
# 0  Najibullah Zadran  Mirwais Ashraf  Dawlat Zadran  Hamid Hassan
# 1        Afsar Zazai  Mirwais Ashraf  Dawlat Zadran    Aftab Alam
# 2  Najibullah Zadran  Mirwais Ashraf     Aftab Alam  Hamid Hassan
# 3        Afsar Zazai  Mirwais Ashraf  Dawlat Zadran  Hamid Hassan
# 4  Najibullah Zadran     Afsar Zazai  Dawlat Zadran  Hamid Hassan
#
#               p11
# 0      Aftab Alam
# 1    Hamid Hassan
# 2  Shapoor Zadran
# 3  Shapoor Zadran
# 4  Shapoor Zadran

# %%
#load data file
Batsmen = pd.read_csv('BtScore2.csv')

# %%
Batsmen.head()
# Out:
#                         player  Batsmen_score              Name
# 0         SR Tendulkar (INDIA)      74.578055      SR Tendulkar
# 1  KC Sangakkara (Asia/ICC/SL)      59.823345     KC Sangakkara
# 2      ST Jayasuriya (Asia/SL)      56.100457     ST Jayasuriya
# 3         RT Ponting (AUS/ICC)      55.584678        RT Ponting
# 4   DPMD Jayawardene (Asia/SL)      51.517991  DPMD Jayawardene

# %%
players = ['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','p11']

# %%
sumslist = []

# %%
for index, row in data.iterrows():
        sums = 0
        for ind, p in enumerate(players):
            player = data.iloc[index][p]
            value = Batsmen[Batsmen['Name']==player]['Batsmen_score'].values
            
            try:
                sums = sums + value[0]
            except IndexError:
                pass
                
        print(sums)
        sumslist.append(sums)
# Out:
# 82.56753173
# 89.77404032399998
# 89.75101152799999
# 92.85207042799999
# 96.51158902799999
# 96.51158902799999
# 83.686603828
# 104.271020526
# 109.572116626
# 102.716176026
# 103.336313326
# 106.25844932199999
# 106.087732632
# 105.63685683199999
# 103.961112822
# 112.12019855999999
# 95.357389366
# 94.531510556
# 94.531510556
# 113.90643436
# 113.90643436
# 113.90643435999999
# 125.25000585999999
# 122.89578446
# 122.89578446
# 106.59285895
# 121.82620183999998
# 121.574537256
# 121.574537256
# 121.574537256
# 139.96842595
# 143.41263766
# 118.48030214999999
# 116.80295419299999
# 125.24070925000001
# 124.13218223999999
# 82.44792464199999
# 93.81047134199999
# 85.47367275199998
# 85.47367275199998
# 85.47367275199998
# 130.76471653399997
# 130.76471653399997
# 126.703290579
# 127.024397146
# 127.024397146
# 133.85064004000003
# 133.85064004000003
# 133.85064004000003
# 133.85064004000003
# 133.42005843400003
# 130.57950534000003
# 130.57950534000003
# 126.99334523999998
# 132.21106354600002
# 129.722212246
# 143.00007155
# 143.00007155
# 72.325737646
# 72.325737646
# 89.846366956
# 80.52147734600001
# 77.66783764600001
# 145.00094085400002
# 148.616325654
# 148.616325654
# 138.96629404400002
# 142.900274354
# 140.889599748
# 140.40488723800001
# 147.962708138
# 143.88875064400003
# 122.519347006
# 94.288099783
# 94.288099783

# %%
data['Batsmen Score'] = sumslist

# %%
#load data file
Bowlers = pd.read_csv('BwScore2.csv')

# %%
Bowlers.head()
# Out:
#                          Player  Bowlers_score            Name
# 0            Waqar Younis (PAK)      12.740990    Waqar Younis
# 1  M Muralitharan (Asia/ICC/SL)      10.996540  M Muralitharan
# 2                   B Lee (AUS)      10.109450           B Lee
# 3             Wasim Akram (PAK)       8.937963     Wasim Akram
# 4               SL Malinga (SL)       8.707719      SL Malinga

# %%
sumslist = []
for index, row in data.iterrows():
        sums = 0
        for ind, p in enumerate(players):
            player = data.iloc[index][p]
            value = Bowlers[Bowlers['Name']==player]['Bowlers_score'].values
            
            try:
                sums = sums + value[0]
            except IndexError:
                pass
                
        print(sums)
        sumslist.append(sums)
# Out:
# 11.230552000000001
# 12.566872000000002
# 12.359831000000002
# 12.831456000000001
# 12.703939
# 12.703939
# 10.579023
# 10.844152999999999
# 13.742748999999998
# 13.742748999999998
# 13.368610999999998
# 12.671259
# 11.18623
# 10.466445
# 12.671259
# 12.462671
# 14.673974999999999
# 15.983854
# 16.464785999999997
# 14.908277999999997
# 17.239618999999998
# 12.955108000000001
# 14.035366999999999
# 14.274735999999999
# 14.242481999999999
# 14.242481999999999
# 14.760631
# 13.468856
# 15.578802
# 15.578802
# 15.578802
# 15.578802
# 15.281192
# 15.097939000000002
# 16.987686
# 16.987686
# 16.411425
# 16.411425
# 16.162835
# 15.002541
# 15.002540999999999
# 15.002541
# 14.144365999999998
# 16.64098
# 14.438652999999999
# 18.062141
# 17.739463
# 17.739463
# 14.530916
# 14.530916
# 14.530916
# 14.530916
# 15.867236
# 14.530916
# 15.867236000000002
# 15.002540999999999
# 14.080084000000001
# 14.530916
# 16.333736
# 16.159999
# 14.277439999999999
# 15.777759999999999
# 15.777759999999999
# 13.254301
# 14.340507
# 15.002540999999999
# 14.530916
# 16.338861
# 16.571203
# 17.664588000000002
# 15.879293
# 15.021117999999998
# 14.229084
# 21.566982999999997
# 13.244878000000002
# 13.244878000000002
# 16.511170999999997
# 17.100452
# 18.855117
# 18.828106
# 16.602463999999998
# 17.424727999999998
# 17.424727999999998
# 15.171986
# 15.564305000000001
# 15.564305000000001
# 13.161847999999999
# 13.44311
# 13.106783
# 12.943190000000001
# 12.005764
# 12.005764000000003
# 12.616933
# 12.616933000000001
# 12.616933
# 15.630865000000004
# 15.497665000000003
# 15.497665000000003
# 13.864416000000002
# 13.713018000000002
# 14.695877
# 14.695877
# 14.695877
# 13.967609
# 15.851727
# 17.816428
# 13.096778
# 14.716064999999999
# 14.755232
# 13.931683
# 13.960909000000001
# 14.455760999999999
# 14.455760999999999
# 14.455760999999999
# 15.561708999999999
# 15.561708999999999
# 12.644978
# 14.875277
# 14.875277
# 15.141858999999998
# 15.141858999999998
# 15.141858999999998
# 15.141858999999998
# 17.201155999999997
# 17.035385
# 17.035385
# 14.739426
# 14.410787
# 15.905267
# 15.052129999999998
# 15.052129999999998
# 10.627519
# 10.627519
# 9.295347
# 9.541295999999999
# 11.525514
# 13.124475
# 13.433601999999999
# 13.433601999999999
# 11.724239999999998
# 13.280999999999999
# 13.686554
# 11.807148999999999
# 13.319790999999999
# 13.763476999999998
# 12.401829000000001
# 7.745423
# 7.745423

# %%
data['Bowlers Score'] = sumslist

# %%
#load data file
Fielders = pd.read_csv('fielders.csv')

# %%
Fielders.head()
# Out:
#                         Player  Fielders_score           Name
# 0  KC Sangakkara (Asia/ICC/SL)      230.885000  KC Sangakkara
# 1       AC Gilchrist (AUS/ICC)      218.378000   AC Gilchrist
# 2        MS Dhoni (Asia/INDIA)      206.738300       MS Dhoni
# 3          MV Boucher (Afr/SA)      200.638000     MV Boucher
# 4              Moin Khan (PAK)      134.335151      Moin Khan

# %%
sumslist = []
for index, row in data.iterrows():
        sums = 0
        for ind, p in enumerate(players):
            player = data.iloc[index][p]
            value = Fielders[Fielders['Name']==player]['Fielders_score'].values
            
            try:
                sums = sums + value[0]
            except IndexError:
                pass
                
        print(sums)
        sumslist.append(sums)
# Out:
# 98.42195742999999
# 106.18310594500001
# 106.839705945
# 112.377105945
# 109.18890594499999
# 109.18890594499999
# 104.42290594499998
# 143.909654455
# 148.519054455
# 144.389254455
# 140.62155445500002
# 150.26095445500002
# 142.05670594
# 141.72425742500002
# 143.57385445500003
# 136.80300594000002
# 140.50850594
# 150.52275446
# 150.10335446
# 148.34005446
# 143.95865446
# 138.70315446
# 143.64855446
# 152.66305446
# 148.27415446
# 148.27415446
# 145.64830594499998
# 131.741105945
# 153.66865446
# 146.98155446
# 149.53885446
# 149.53885446
# 139.58445446000002
# 139.88215446
# 115.989957435
# 115.989957435
# 101.17440594499999
# 101.17440594499999
# 99.76500594499998
# 142.62895446
# 142.62895446000002
# 142.62895446
# 138.34410594499997
# 134.27800594500002
# 130.56060594499996
# 142.60495446000002
# 149.703102975
# 149.703102975
# 94.816802975
# 138.01915148999998
# 139.45820297499998
# 139.458202975
# 138.16560297499998
# 139.45820297499998
# 138.16560297499998
# 143.55655149
# 213.86805149
# 213.86805149
# 213.86805149
# 210.60775148999997
# 212.18375148999996
# 205.85175148999997
# 124.47950296999998
# 124.47950296999998
# 122.341554455
# 117.066754455
# 117.066754455
# 118.642754455
# 118.93300594
# 118.93300593999997
# 115.940157425
# 115.37470594
# 119.221354455
# 117.35150593999998
# 110.14215742500001
# 112.90790594
# 112.90790594
# 179.582154455
# 180.038354455
# 179.637554455
# 158.62905742499998
# 151.25350594
# 115.61050594
# 154.82650594
# 185.24220297
# 184.50740297
# 187.02570296999997
# 187.90930296999997
# 162.41860296999997
# 159.57355445499996
# 164.96320296999997
# 143.84380296999998
# 140.38980593999997
# 143.51110593999996
# 141.56800297
# 140.90965148499998
# 136.04040297
# 136.663354455
# 163.02305148499997
# 165.110951485
# 165.110951485
# 165.110951485
# 127.106254455
# 126.87670594
# 129.00710594
# 126.90695742499999
# 123.21665742499998
# 170.549051485
# 163.287451485
# 158.8482
# 167.6731
# 167.427851485
# 157.71270296999998
# 149.70610297
# 162.943151485
# 164.96069999999997
# 162.91450296999997
# 130.68515148499998
# 130.68515148499998
# 112.28630297
# 127.89100297000002
# 132.00290296999998
# 132.00290297
# 117.391751485
# 110.95890297
# 104.79860297
# 134.58490297
# 135.445354455
# 133.51830296999998
# 222.55621190000002
# 306.412763395
# 225.05891190000003
# 211.37801190000002
# 211.37801190000002
# 186.61976041500003
# 153.6304119
# 173.67266042
# 168.59026042
# 175.73096042499998
# 193.68041191
# 193.68041191
# 169.509911905
# 160.09076339
# 160.09076339
# 131.935563385
# 143.576460415
# 136.6483119
# 118.709863385
# 121.03231189499999
# 121.03231189499999
# 136.34381190000002
# 136.34381190000002
# 136.34381190000002
# 154.226811905
# 151.85481190500002
# 151.85481190500002
# 142.02016042000002
# 155.95590893000002
# 156.210411905
# 156.210411905
# 156.210411905
# 176.32036042
# 180.40391191
# 151.75676041500003
# 142.11671190500002
# 144.86396041500004
# 136.706208925
# 107.02716040499999
# 120.044860405
# 111.07561189499998
# 111.07561189499998
# 111.07561189499998
# 143.28935744
# 143.28935744
# 140.94186041
# 148.38306041
# 148.38306041
# 198.10410892500002
# 198.10410892500002
# 198.10410892500002
# 198.10410892500002
# 188.614157435
# 185.57250892000002
# 185.57250892
# 182.37360892
# 185.740860405
# 183.681560405
# 191.61856041000001
# 191.61856041000001
# 91.67596040499998
# 91.67596040499998
# 110.734911895
# 101.46086040499998
# 107.28786040499998
# 207.70596041500002
# 208.69746041500002
# 208.69746041500002
# 190.51520892500002
# 204.16906041500002
# 200.07770893000003
# 192.17735744
# 199.38435744
# 204.232108925
# 222.533951485
# 156.621363385
# 156.621363385

# %%
data['Fielders Score'] = sumslist

# %%
batList = []
bowlList = []
fieldList = []
for index, row in data.iterrows():
    inning = data.iloc[index]['Innings ID']
    if(inning%2 == 1):
        inning = inning + 1
    else:
        inning = inning - 1
    batList.append(data[data['Innings ID']==inning]['Batsmen Score'].values[0])
    bowlList.append(data[data['Innings ID']==inning]['Bowlers Score'].values[0])
    fieldList.append(data[data['Innings ID']==inning]['Fielders Score'].values[0])

# %%
data['Opposite Batsmen Score'] = batList
data['Opposite Bowlers Score'] = bowlList
data['Opposite Fielders Score'] = fieldList

# %%
data.head()
# Out:
#    Innings ID         Team Day_Night  Home       Ground Result  Toss  Bat  \
# 0        1016  Afghanistan        DN     0  Dubai (DSC)   lost  lost  1st
# 1        1025  Afghanistan         D     0  Dubai (DSC)    won  lost  1st
# 2        1068  Afghanistan        DN     0     Canberra   lost  lost  2nd
# 3        1074  Afghanistan         D     0      Dunedin   lost  lost  1st
# 4        1092  Afghanistan        DN     0        Perth   lost   won  2nd
#
#      Opposition            p1  ...              p8             p9  \
# 0     v Ireland  Javed Ahmadi  ...  Mirwais Ashraf  Dawlat Zadran
# 1     v Ireland  Javed Ahmadi  ...  Mirwais Ashraf  Dawlat Zadran
# 2  v Bangladesh  Javed Ahmadi  ...  Mirwais Ashraf     Aftab Alam
# 3   v Sri Lanka  Javed Ahmadi  ...  Mirwais Ashraf  Dawlat Zadran
# 4   v Australia  Javed Ahmadi  ...     Afsar Zazai  Dawlat Zadran
#
#             p10             p11 Batsmen Score Bowlers Score Fielders Score  \
# 0  Hamid Hassan      Aftab Alam     82.567532     11.230552      98.421957
# 1    Aftab Alam    Hamid Hassan     89.774040     12.566872     106.183106
# 2  Hamid Hassan  Shapoor Zadran     89.751012     12.359831     106.839706
# 3  Hamid Hassan  Shapoor Zadran     92.852070     12.831456     112.377106
# 4  Hamid Hassan  Shapoor Zadran     96.511589     12.703939     109.188906
#
#   Opposite Batsmen Score Opposite Bowlers Score Opposite Fielders Score
# 0             153.582926              12.917185              207.860709
# 1             153.582926              12.917185              207.860709
# 2             193.552285              18.695195              373.241000
# 3             244.934803              26.394802              470.796700
# 4             180.413890              27.237640              269.240700
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
data['Team'] = label.fit_transform(data['Team'])
data['Day_Night'] = label.fit_transform(data['Day_Night'])
data['Ground'] = label.fit_transform(data['Ground'])
data['Toss'] = label.fit_transform(data['Toss'])
data['Bat'] = label.fit_transform(data['Bat'])
data['Opposition'] = label.fit_transform(data['Opposition'])

# %%
feature_names = ['Team', 'Day_Night', 'Home', 'Ground', 'Toss', 'Bat', 'Opposition', 'Batsmen Score', 'Bowlers Score', 'Fielders Score', 'Opposite Batsmen Score', 'Opposite Bowlers Score', 'Opposite Fielders Score']
X = data[feature_names]
Y = data['Result']

# %%
#split the data set as training set and test set randomly
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=0)

# %%
#apply scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#use model Logistic Regression
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
# get importance
importance = logreg.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature:%0d -> %s, Score: %.5f' % (i,feature_names[i],v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.xticks(np.arange(len(feature_names)), feature_names,rotation='vertical')
plt.show()
# Out:
# Accuracy of Logistic regression classifier on training set: 0.68
# Accuracy of Logistic regression classifier on test set: 0.67
# Feature:0 -> Team, Score: -0.85774
# Feature:1 -> Day_Night, Score: 0.17237
# Feature:2 -> Home, Score: 0.88693
# Feature:3 -> Ground, Score: 0.03549
# Feature:4 -> Toss, Score: -0.25859
# Feature:5 -> Bat, Score: 0.05465
# Feature:6 -> Opposition, Score: 0.92851
# Feature:7 -> Batsmen Score, Score: 1.05085
# Feature:8 -> Bowlers Score, Score: 0.35997
# Feature:9 -> Fielders Score, Score: 0.87116
# Feature:10 -> Opposite Batsmen Score, Score: -1.07321
# Feature:11 -> Opposite Bowlers Score, Score: -0.31953
# Feature:12 -> Opposite Fielders Score, Score: -1.44647

# %%
#use model Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier().fit(X_train, y_train)

print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.59

# %%
#use model Decision Tree Classifier with maximum depth of 3
clf2 = DecisionTreeClassifier(max_depth=3).fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf2.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf2.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.67
# Accuracy of Decision Tree classifier on test set: 0.63

# %%
#use model Decision Tree Classifier with maximum depth of 4
clf2 = DecisionTreeClassifier(max_depth=4).fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf2.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf2.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.70
# Accuracy of Decision Tree classifier on test set: 0.59

# %%
#use model k-neighbours
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.77
# Accuracy of K-NN classifier on test set: 0.56

# %%
#use model Linear Discriminant Analysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train)
print('Accuracy of LDA classifier on training set: {:.2f}'
     .format(lda.score(X_train, y_train)))
print('Accuracy of LDA classifier on test set: {:.2f}'
     .format(lda.score(X_test, y_test)))
# Out:
# Accuracy of LDA classifier on training set: 0.67
# Accuracy of LDA classifier on test set: 0.68

# %%
#use model Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)
print('Accuracy of GNB classifier on training set: {:.2f}'
     .format(gnb.score(X_train, y_train)))
print('Accuracy of GNB classifier on test set: {:.2f}'
     .format(gnb.score(X_test, y_test)))
# Out:
# Accuracy of GNB classifier on training set: 0.69
# Accuracy of GNB classifier on test set: 0.67

# %%
#use model support vector machine
from sklearn.svm import SVC

svm = SVC()
svm.fit(X_train, y_train)
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(svm.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.2f}'
     .format(svm.score(X_test, y_test)))
# Out:
# Accuracy of SVM classifier on training set: 0.74
# Accuracy of SVM classifier on test set: 0.65

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

rfc = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)
rfc.fit(X_train, y_train)
print('Accuracy of RFC classifier on training set: {:.2f}'
     .format(rfc.score(X_train, y_train)))
print('Accuracy of RFC classifier on test set: {:.2f}'
     .format(rfc.score(X_test, y_test)))
# Out:
# Accuracy of RFC classifier on training set: 0.72
# Accuracy of RFC classifier on test set: 0.66

# %%
ABC = AdaBoostClassifier(n_estimators=100)
ABC.fit(X_train, y_train)
print('Accuracy of ABC classifier on training set: {:.2f}'
     .format(ABC.score(X_train, y_train)))
print('Accuracy of ABC classifier on test set: {:.2f}'
     .format(ABC.score(X_test, y_test)))
# Out:
# Accuracy of ABC classifier on training set: 0.78
# Accuracy of ABC classifier on test set: 0.60

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
Qda = QuadraticDiscriminantAnalysis()
Qda.fit(X_train, y_train)
print('Accuracy of QDA classifier on training set: {:.2f}'
     .format(Qda.score(X_train, y_train)))
print('Accuracy of QDA classifier on test set: {:.2f}'
     .format(Qda.score(X_test, y_test)))
# Out:
# Accuracy of QDA classifier on training set: 0.73
# Accuracy of QDA classifier on test set: 0.66

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
GPC = GaussianProcessClassifier()
GPC.fit(X_train, y_train)
print('Accuracy of GPC classifier on training set: {:.2f}'
     .format(GPC.score(X_train, y_train)))
print('Accuracy of GPC classifier on test set: {:.2f}'
     .format(GPC.score(X_test, y_test)))
# Out:
# Accuracy of GPC classifier on training set: 0.73
# Accuracy of GPC classifier on test set: 0.66

# %%
svm2 = SVC(gamma=2, C=1)
svm2.fit(X_train, y_train)
print('Accuracy of svm2 classifier on training set: {:.2f}'
     .format(svm2.score(X_train, y_train)))
print('Accuracy of svm2 classifier on test set: {:.2f}'
     .format(svm2.score(X_test, y_test)))
# Out:
# Accuracy of svm2 classifier on training set: 0.81
# Accuracy of svm2 classifier on test set: 0.65

# %%
from sklearn.neural_network import MLPClassifier 
mlp = MLPClassifier(alpha=1, max_iter=1000)
mlp.fit(X_train, y_train)
print('Accuracy of svm2 classifier on training set: {:.2f}'
     .format(mlp.score(X_train, y_train)))
print('Accuracy of svm2 classifier on test set: {:.2f}'
     .format(mlp.score(X_test, y_test)))
# Out:
# Accuracy of svm2 classifier on training set: 0.68
# Accuracy of svm2 classifier on test set: 0.68

# %%
from sklearn.gaussian_process.kernels import RBF
gpc_rbf = GaussianProcessClassifier(1.0 * RBF(1.0))
gpc_rbf.fit(X_train, y_train)
print('Accuracy of gpc_rbf classifier on training set: {:.2f}'
     .format(gpc_rbf.score(X_train, y_train)))
print('Accuracy of gpc_rbf classifier on test set: {:.2f}'
     .format(gpc_rbf.score(X_test, y_test)))
# Out:
# Accuracy of gpc_rbf classifier on training set: 0.70
# Accuracy of gpc_rbf classifier on test set: 0.67

# %%
svm3 = SVC(kernel="linear", C=0.003)
svm3.fit(X_train, y_train)
print('Accuracy of svm3 classifier on training set: {:.2f}'
     .format(svm3.score(X_train, y_train)))
print('Accuracy of svm3 classifier on test set: {:.2f}'
     .format(svm3.score(X_test, y_test)))
# Out:
# Accuracy of svm3 classifier on training set: 0.51
# Accuracy of svm3 classifier on test set: 0.46

# %%
#xgboost
from xgboost import XGBClassifier
modelxg = XGBClassifier()
modelxg.fit(X_train, y_train)
print('Accuracy of xgboost classifier on training set: {:.2f}'
     .format(modelxg.score(X_train, y_train)))
print('Accuracy of xgboost classifier on test set: {:.2f}'
     .format(modelxg.score(X_test, y_test)))
# Out:
# c:\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:10:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy of xgboost classifier on training set: 1.00
# Accuracy of xgboost classifier on test set: 0.61
